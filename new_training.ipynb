# %% [markdown]
# # Lancio di un training con le nuove specs

# %%
from smash_rl import train
from smash_rl.runs import launch, list_runs, status
import subprocess

# %% [markdown]
# ## Debug pre run

# %%
# lancio di pytest per verificare sia tutto a posto prima di addestrare
subprocess.run(["pytest", "-q", "--disable-warnings", "--tb=short"], check=True)
# Out:
# ........................................................................ [ 55%]
# ..........................................................               [100%]
# 130 passed, 6 deselected in 6.37s
# CompletedProcess(args=['pytest', '-q', '--disable-warnings', '--tb=short'], returncode=0)

# %%
for run in list_runs():
    for key, value in run.items():
        print(f"{key}: {value}")
# Out:
# run_id: 1
# run_name: new_specs_test
# pid: 3282891
# pid_create_time: 1783686298.78
# instance_base: 0
# n_envs: 4
# config_path: /home/luca/Desktop/Code/smash/runs/new_specs_test/config.json
# log_path: /home/luca/Desktop/Code/smash/runs/new_specs_test/train.log
# started_at: 2026-07-10T14:24:59
# status: running
# algo: dqn
# total_steps: 1000000

# %% [markdown]
# ## Run

# %%
cfg = train.TrainConfig(
    run_name="new_specs_test",
    total_steps=1_000_000,
)

cfg.env_kwargs["observation_function"] = "pos_vel_facing_state"
launch(cfg)
